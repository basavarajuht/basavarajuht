# %% [markdown]
# <a href="https://colab.research.google.com/github/basavarajuht/basavarajuht/blob/main/readfromdrive.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2
import matplotlib.pyplot as plt

# %%
img=cv2.imread('/content/drive/MyDrive/BrainClassification/dataset/test/N1.jpeg')

# %%
plt.imshow(img)
plt.show()

# %%
import os
import cv2
import matplotlib.pyplot as plt

# Specify the path to the folder containing your images
folder_path = '/content/drive/MyDrive/BrainClassification/dataset/test'

# Get a list of all image files in the folder
image_files = [f for f in os.listdir(folder_path) if f.endswith(('.jpg', '.png', '.jpeg', '.gif'))]

# Read and display each image
for filename in image_files:
    # Construct the full path to the image file
    image_path = os.path.join(folder_path, filename)

    # Read the image using OpenCV
    image = cv2.imread(image_path)

    if image is not None:
        # Display the image
        plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))  # Convert BGR to RGB for display
        plt.title(filename)
        plt.axis('off')
        plt.show()
    else:
        print(f"Failed to read image: {filename}")
